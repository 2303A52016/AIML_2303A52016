# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52016/AIML_2303A52016/blob/main/Lab01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lists
# Arrays

# %%
import numpy as np

lst1 = [1,2,3,4,5,6]
array1 = np.array(lst1)
array1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# type()

# %%
print(type(array1))
type(array1)
# Out:
# <class 'numpy.ndarray'>
# numpy.ndarray

# %% [markdown]
# Performing mathematical operations like multiplication and division

# %%
lst2 = [7,8,9,10,11,12]
array2 = np.array(lst2)
print("Multiplication: ",array1*array2)
print("Division: ",array1/array2)
# Out:
# Multiplication:  [ 7 16 27 40 55 72]
# Division:  [0.14285714 0.25       0.33333333 0.4        0.45454545 0.5       ]

# %% [markdown]
# Addition of 2 arrays.

# %%
print("Addition: ",array1+array2)
# Out:
# Addition:  [ 8 10 12 14 16 18]

# %% [markdown]
# Implementing np.sin(), log(), log2(), np.exp())

# %%
sintheta = np.sin(array1)
print("sin(theta): ",sintheta,"\n")
log = np.log(array1)
print("log: ",log,"\n")
log2 = np.log2(array1)
print("log2: ",log2,"\n")
exp = np.exp(array1)
print("exp: ",exp,"\n")

sintheta2 = np.sin(array2)
print("sin(theta2): ",sintheta2,"\n")
log2_2 = np.log2(array2)
print("log2_2: ",log2_2,"\n")
log_2 = np.log(array2)
print("log_2: ",log_2,"\n")
exp_2 = np.exp(array2)
print("exp(2): ",exp_2,"\n")
# Out:
# sin(theta):  [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427 -0.2794155 ]
#
# log:  [0.         0.69314718 1.09861229 1.38629436 1.60943791 1.79175947]
#
# log2:  [0.         1.         1.5849625  2.         2.32192809 2.5849625 ]
#
# exp:  [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591
#  403.42879349]
#
# sin(theta2):  [ 0.6569866   0.98935825  0.41211849 -0.54402111 -0.99999021 -0.53657292]
#
# log2_2:  [2.80735492 3.         3.169925   3.32192809 3.45943162 3.5849625 ]
#
# log_2:  [1.94591015 2.07944154 2.19722458 2.30258509 2.39789527 2.48490665]
#
# exp(2):  [  1096.63315843   2980.95798704   8103.08392758  22026.46579481
#   59874.1417152  162754.791419  ]

# %% [markdown]
# Part 2 – Visualization of Data using matplotlib, pyplots Packages[CO2]

# %% [markdown]
# Let's suppose we collected age in 'years' and height in 'cm' and weight in 'kg' information for patients visiting a clinic

# %%
people = ['kiran', 'arun', 'vijay', 'varun', 'ravi']
age =[25, 30, 35, 40, 45]
height =[145, 151, 165, 173, 159]
weight=[45, 55, 65, 75, 77]

# %%
import matplotlib.pyplot as plt

plt.scatter(weight, height)
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Weight vs Height')
plt.show()

# %% [markdown]
# Now, Representing the given data in Bar Graph

# %%
plt.bar(x=people, height=age, color = 'blue', alpha = 0.6)
plt.xticks(fontsize = 16, rotation = 45) # Set fontsize for x-axis tick labels
plt.yticks(fontsize = 16) # Set fontsize for y-axis tick labels
plt.xlabel('People')
plt.ylabel('Age')
plt.title('Age of People')
plt.show()

# %% [markdown]
# Part 3: Access data from a dataset using functions like Numpy, Pandas

# %% [markdown]
# Now, for the above data create charts for all of them.

# %%
import pandas as pd # Import the pandas library and alias it as 'pd'
import matplotlib.pyplot as plt # Import the matplotlib.pyplot library and alias it as 'plt'
import numpy as np

data1 = pd.read_csv('/content/HistoricalPrices.csv') # Use the correct function name
data1.head()
# Out:
#        Date      Open      High       Low     Close
# 0  08/07/24  39230.09  39477.96  38731.51  38763.45
# 1  08/06/24  38736.22  39449.53  38638.30  38997.66
# 2  08/05/24  39056.19  39056.19  38499.27  38703.27
# 3  08/02/24  40075.33  40075.33  39358.68  39737.26
# 4  08/01/24  40916.96  41096.66  40098.57  40347.97

# %%
# @title  Low vs  Close

from matplotlib import pyplot as plt
data1.plot(kind='scatter', x=' Low', y=' Close', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title  Open vs  High

from matplotlib import pyplot as plt
data1.plot(kind='scatter', x=' Open', y=' High', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title  Close

from matplotlib import pyplot as plt
data1[' Close'].plot(kind='hist', bins=20, title=' Close')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title  Low

from matplotlib import pyplot as plt
data1[' Low'].plot(kind='hist', bins=20, title=' Low')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title  High

from matplotlib import pyplot as plt
data1[' High'].plot(kind='hist', bins=20, title=' High')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title  Open

from matplotlib import pyplot as plt
data1[' Open'].plot(kind='hist', bins=20, title=' Open')
plt.gca().spines[['top', 'right',]].set_visible(False)
